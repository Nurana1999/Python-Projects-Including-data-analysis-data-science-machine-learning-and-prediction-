# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/lider/Downloads/4-IPL data Analysis/deliveries.csv")
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
filt=df['batsman']=='DA Warner'

# %%
df_warner=df[filt]

# %%
df_warner.shape
# Out:
# (2902, 21)

# %%
df_warner.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df_warner['dismissal_kind'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='dismissal_kind'>

# %%
len(df_warner[df_warner['batsman_runs']==4])
# Out:
# 401

# %%
def funk(runs):
    return len(df_warner[df_warner['batsman_runs']==runs])

# %%
funk(6)
# Out:
# 160

# %%
df_warner['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Gujarat Lions', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Rising Pune Supergiant', 'Chennai Super Kings', 'Deccan Chargers',
#        'Rajasthan Royals', 'Pune Warriors', 'Kochi Tuskers Kerala',
#        'Sunrisers Hyderabad', 'Rising Pune Supergiants'], dtype=object)

# %%
df_warner['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Delhi Daredevils'], dtype=object)

# %%
Teams={'Sunrisers Hyderabad':'SH', 'Delhi Daredevils':'DD'}

# %%
df['batting_team']=df['batting_team'].map(Teams)

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1           SH          RCB     1     1  DA Warner
# 1         1       1           SH          RCB     1     2  DA Warner
# 2         1       1           SH          RCB     1     3  DA Warner
# 3         1       1           SH          RCB     1     4  DA Warner
# 4         1       1           SH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
Teams={'Royal Challengers Bangalore':'RCB', 'Gujarat Lions':'GL', 'Mumbai Indians':'MI',
       'Kolkata Knight Riders':'KKR', 'Kings XI Punjab':'KP', 'Delhi Daredevils':'DD',
       'Rising Pune Supergiant':'RPS', 'Chennai Super Kings':'CSK', 'Deccan Chargers':'DC',
       'Rajasthan Royals':'RR', 'Pune Warriors':'PW', 'Kochi Tuskers Kerala':'KTK',
       'Sunrisers Hyderabad':'SH', 'Rising Pune Supergiants':'RPS'}

# %%
df['bowling_team']=df['bowling_team'].map(Teams)

# %%
df.head()
# Out:
#    match_id  inning         batting_team bowling_team  over  ball    batsman  \
# 0         1       1  Sunrisers Hyderabad          RCB     1     1  DA Warner
# 1         1       1  Sunrisers Hyderabad          RCB     1     2  DA Warner
# 2         1       1  Sunrisers Hyderabad          RCB     1     3  DA Warner
# 3         1       1  Sunrisers Hyderabad          RCB     1     4  DA Warner
# 4         1       1  Sunrisers Hyderabad          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# ...

# %%
df.groupby(['match_id','inning','batting_team'])['total_runs'].sum()
# Out:
# match_id  inning  batting_team
# 1         1       SH              207
# 5         2       DD              142
# 6         2       SH              140
# 9         1       DD              205
# 10        1       SH              158
#                                  ...
# 631       2       SH              149
# 632       1       DD              138
# 634       1       SH              162
# 635       2       SH              163
# 636       1       SH              208
# Name: total_runs, Length: 225, dtype: int64

# %%
runs=df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
runs.drop('match_id',axis=1,inplace=True)
runs
# Out:
#      inning batting_team  total_runs
# 0         1           SH         207
# 1         2           DD         142
# 2         2           SH         140
# 3         1           DD         205
# 4         1           SH         158
# ..      ...          ...         ...
# 220       2           SH         149
# 221       1           DD         138
# 222       1           SH         162
# 223       2           SH         163
# 224       1           SH         208
#
# [225 rows x 3 columns]

# %%
inning1=runs[runs['inning']==1]
inning2=runs[runs['inning']==2]

# %%
balls=df.groupby('batsman')['ball'].count().reset_index()
balls
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %%
runs=df.groupby('batsman')['batsman_runs'].sum().reset_index()
runs
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %%
four=df_warner[df_warner['batsman_runs']==4]
four
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 8              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1334           6       2  Sunrisers Hyderabad                Gujarat Lions
# 1352           6       2  Sunrisers Hyderabad                Gujarat Lions
# 1353           6       2  Sunrisers Hyderabad                Gujarat Lions
# ...          ...     ...                  ...                          ...
# 150262       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150264       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150266       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150267       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150291       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
#
# ...

# %%
runs_4=four.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4
# Out:
#      batsman  batsman_runs
# 0  DA Warner           401
